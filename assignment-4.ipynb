# %%
import numpy as np
import pandas as pd

# %%
hotel_data=pd.read_csv("hotel_bookings.csv")

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119389 non-null  float64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel_data.isna()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
hotel_data.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 1
# children                               4
# babies                                 0
# meal                                   0
# country                              507
# market_segment                         2
# distribution_channel                   1
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     1
# assigned_room_type                     1
# booking_changes                        0
# deposit_type                          21
# ...

# %%
hotel_data['children'].fillna(hotel_data['children'].mean(),inplace=True)
hotel_data['country'].fillna(hotel_data['country'].mode()[0],inplace=True)
hotel_data['market_segment'].fillna(hotel_data['market_segment'].mode()[0],inplace=True)
hotel_data['distribution_channel'].fillna(hotel_data['distribution_channel'].mode()[0],inplace=True)
hotel_data['deposit_type'].fillna(hotel_data['deposit_type'].mode()[0],inplace=True)
hotel_data['reserved_room_type'].fillna(hotel_data['reserved_room_type'].mode()[0],inplace=True)
hotel_data['assigned_room_type'].fillna(hotel_data['assigned_room_type'].mode()[0],inplace=True)
hotel_data['adults'].fillna(hotel_data['adults'].mean(),inplace=True)
hotel_data['reservation_status'].fillna(hotel_data['reservation_status'].mode()[0],inplace=True)
hotel_data['customer_type'].fillna(hotel_data['customer_type'].mode()[0],inplace=True)
hotel_data['agent'].fillna(hotel_data['agent'].median(),inplace=True)

# %%
hotel_data.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
hotel_data.drop('company', axis=1, inplace=True)

# %%
hotel_data.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
hotel_data[hotel_data.duplicated()]
hotel_data.drop_duplicates(inplace=True)

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87374 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87374 non-null  object
#  1   is_canceled                     87374 non-null  int64
#  2   lead_time                       87374 non-null  int64
#  3   arrival_date_year               87374 non-null  int64
#  4   arrival_date_month              87374 non-null  object
#  5   arrival_date_week_number        87374 non-null  int64
#  6   arrival_date_day_of_month       87374 non-null  int64
#  7   stays_in_weekend_nights         87374 non-null  int64
#  8   stays_in_week_nights            87374 non-null  int64
#  9   adults                          87374 non-null  float64
#  10  children                        87374 non-null  float64
#  11  babies                          87374 non-null  int64
# ...

# %%
Q1 = hotel_data['is_canceled'].quantile(0.25)
Q3 = hotel_data['is_canceled'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers = [(hotel_data['is_canceled'] < (Q1 - 1.5 * IQR)) | (hotel_data['is_canceled'] > (Q3 + 1.5 * IQR))]
print(outliers)
# Out:
# [0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Name: is_canceled, Length: 87374, dtype: bool]

# %%
n1=sum(outliers)
n1.sum()
# Out:
# 0

# %%
Q1 = hotel_data['agent'].quantile(0.25)
Q3 = hotel_data['agent'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers = [(hotel_data['agent'] < (Q1 - 1.5 * IQR)) | (hotel_data['agent'] > (Q3 + 1.5 * IQR))]
print(outliers)
# Out:
# [0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Name: agent, Length: 87374, dtype: bool]

# %%
Q1 = hotel_data['lead_time'].quantile(0.25)
Q3 = hotel_data['lead_time'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers = [(hotel_data['lead_time'] < (Q1 - 1.5 * IQR)) | (hotel_data['lead_time'] > (Q3 + 1.5 * IQR))]
n1=sum(outliers)
n1.sum()
# Out:
# 2397

# %%
import seaborn as sns
sns.boxplot(hotel_data['lead_time'])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
numerical_columns = [ 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'previous_cancellations', 'previous_bookings_not_canceled', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']

# Visual inspection of outliers
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(y=hotel_data[column])
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()

# %%
def handle_outliers(df, columns):
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
        df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])
    
    return df
booking_detail_cleaned = handle_outliers(hotel_data.copy(), numerical_columns)
plt.figure(figsize=(15, 10))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(y=booking_detail_cleaned[column])
    plt.title(f'Boxplot of {column} after Outlier Handling')
plt.tight_layout()
plt.show()

# %%
hotel_data.describe()
hotel_data.describe(include='object')
categorical_columns = ['hotel', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest',
                       'reserved_room_type', 'assigned_room_type', 'deposit_type', 'agent',
                       'customer_type', 'reservation_status']

for col in categorical_columns:
    print(f"Value counts for {col}:")
    print(hotel_data[col].value_counts())
    print("\n")
# Out:
# Value counts for hotel:
# hotel
# City Hotel      53430
# Resort Hotel    33944
# Name: count, dtype: int64
#
#
# Value counts for country:
# country
# PRT    27886
# GBR    10432
# FRA     8837
# ESP     7252
# DEU     5387
#        ...
# MMR        1
# BFA        1
# CYM        1
# MLI        1
# KHM        1
# Name: count, Length: 177, dtype: int64
#
#
# Value counts for market_segment:
# market_segment
# Online TA        51615
# Offline TA/TO    13885
# Direct           11798
# Groups            4943
# Corporate         4202
# Complementary      702
# Aviation           227
# Undefined            2
# Name: count, dtype: int64
#
#
# Value counts for distribution_channel:
# distribution_channel
# TA/TO        69137
# Direct       12980
# Corporate     5071
# GDS            181
# Undefined        5
# Name: count, dtype: int64
#
#
# Value counts for is_repeated_guest:
# is_repeated_guest
# 0    83959
# 1     3415
# Name: count, dtype: int64
#
#
# Value counts for reserved_room_type:
# ...

# %%
numerical_columns = ['lead_time', 'stays_in_weekend_nights',
'stays_in_week_nights', 'adults', 'children', 'babies', 'previous_cancellations',
'previous_bookings_not_canceled', 'days_in_waiting_list', 'adr',
'required_car_parking_spaces', 'total_of_special_requests']

for col in numerical_columns:
    plt.figure(figsize=(10, 6))
    
    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(hotel_data[col], kde=True, color='skyblue')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    
    # Box plot
    plt.subplot(1, 2, 2)
    sns.boxplot(data=hotel_data, x=col, color='lightgreen')
    plt.title(f'Box plot of {col}')
    plt.xlabel(col)
    
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\sauga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sauga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sauga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
for col in categorical_columns:
    plt.figure(figsize=(8, 6))
    
    # Bar plot
    plt.subplot(1, 2, 1)
    hotel_data[col].value_counts().plot(kind='bar', color='skyblue')
    plt.title(f'Bar plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    
    
    plt.tight_layout()
    plt.show()

# %%
sns.pairplot(hotel_data[numerical_columns])
plt.suptitle('Pairplot of Numerical Columns', y=1.02)
plt.show()

# Heatmap for correlation
plt.figure(figsize=(10, 8))
sns.heatmap(hotel_data[numerical_columns].corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Columns')
plt.show()
# Out:
# C:\Users\sauga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sauga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sauga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
date_columns = ['arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month']

# Convert month names to numeric values for sorting
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
hotel_data['arrival_date_month'] = pd.Categorical(hotel_data['arrival_date_month'], categories=month_order, ordered=True)

# Sort by arrival date
hotel_data_sorted = hotel_data.sort_values(by=['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month'])

# Plotting
plt.figure(figsize=(12, 8))

for col in date_columns:
    plt.plot(hotel_data_sorted[col], label=col)

plt.title('Trends Over Time')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
numerical_columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
                     'babies', 'previous_cancellations', 'previous_bookings_not_canceled', 'days_in_waiting_list',
                     'adr', 'required_car_parking_spaces', 'total_of_special_requests']

correlation_matrix = hotel_data[numerical_columns].corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                 lead_time  stays_in_weekend_nights  \
# lead_time                        1.000000                 0.234866
# stays_in_weekend_nights          0.234866                 1.000000
# stays_in_week_nights             0.309929                 0.555535
# adults                           0.140315                 0.088121
# children                         0.028531                 0.028520
# babies                          -0.003647                 0.013656
# previous_cancellations           0.005345                -0.020648
# previous_bookings_not_canceled  -0.078963                -0.056672
# days_in_waiting_list             0.132923                -0.031853
# adr                              0.023349                 0.038860
# required_car_parking_spaces     -0.086641                -0.042964
# total_of_special_requests        0.034068                 0.032384
#
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
hotel_data_encoded = pd.get_dummies(hotel_data, columns=categorical_columns, drop_first=True)
hotel_data_encoded
# Out:
#         is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0                 0        342               2015               July
# 1                 0        737               2015               July
# 2                 0          7               2015               July
# 3                 0         13               2015               July
# 4                 0         14               2015               July
# ...             ...        ...                ...                ...
# 119385            0         23               2017             August
# 119386            0        102               2017             August
# 119387            0         34               2017             August
# 119388            0        109               2017             August
# 119389            0        205               2017             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 0                             27                          1
# ...

# %%
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data= hotel_data, x=col, order= hotel_data[col].value_counts().index, palette='viridis')
    plt.title(f'Frequency Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# Comparative analysis
for col1 in categorical_columns:
    for col2 in categorical_columns:
        if col1 != col2:
            plt.figure(figsize=(10, 6))
            sns.countplot(data=hotel_data, x=col1, hue=col2, palette='coolwarm')
            plt.title(f'Comparative Analysis: {col1} vs {col2}')
            plt.xlabel(col1)
            plt.ylabel('Count')
            plt.xticks(rotation=45)
            plt.legend(title=col2)
            plt.show()

# Cross-tabulation
for col1 in categorical_columns:
    for col2 in categorical_columns:
        if col1 != col2:
            cross_tab = pd.crosstab(hotel_data[col1], hotel_data[col2])
            print(f'Cross-tabulation between {col1} and {col2}:')
            print(cross_tab)
            print('\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 15
#      13 if col1 != col2:
#      14     plt.figure(figsize=(10, 6))
# ---> 15     sns.countplot(data=hotel_data, x=col1, hue=col2, palette='coolwarm')
#      16     plt.title(f'Comparative Analysis: {col1} vs {col2}')
#      17     plt.xlabel(col1)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
 #Create a contingency table for two categorical columns
contingency_table = pd.crosstab(hotel_data['hotel'], hotel_data['country'])

print("Contingency Table:")
print(contingency_table)
# Out:
# Contingency Table:
# country       ABW  AGO  AIA  ALB  AND  ARE  ARG  ARM  ASM  ATA  ...  UMI  URY  \
# hotel                                                           ...
# City Hotel      2  319    1    8    2   37  147    6    1    2  ...    1   22
# Resort Hotel    0   23    0    3    5   11   56    2    0    0  ...    0    8
#
# country        USA  UZB  VEN  VGB  VNM  ZAF  ZMB  ZWE
# hotel
# City Hotel    1417    3   18    1    6   60    1    2
# Resort Hotel   458    1    3    0    2   18    1    2
#
# [2 rows x 177 columns]

# %%
from statsmodels.graphics.mosaicplot import mosaic

# Create a mosaic plot for two categorical columns
plt.figure(figsize=(10, 6))
mosaic(hotel_data, ['hotel', 'country'], title='Mosaic Plot')
plt.show()

# %%
# Convert reservation_status_date to datetime format with dayfirst=True
hotel_data['reservation_status_date'] = pd.to_datetime(hotel_data['reservation_status_date'], dayfirst=True)

# Extract additional features from the datetime column
hotel_data['reservation_status_day'] = hotel_data['reservation_status_date'].dt.day_name()
hotel_data['reservation_status_month'] = hotel_data['reservation_status_date'].dt.month_name()
hotel_data['reservation_status_hour'] = hotel_data['reservation_status_date'].dt.hour

# Display the first few rows to verify the changes
hotel_data[['reservation_status_date', 'reservation_status_day', 'reservation_status_month', 'reservation_status_hour']].head()
# Out:
#   reservation_status_date reservation_status_day reservation_status_month  \
# 0              2015-07-01              Wednesday                     July
# 1              2015-07-01              Wednesday                     July
# 2              2015-07-02               Thursday                     July
# 3              2015-07-02               Thursday                     July
# 4              2015-07-03                 Friday                     July
#
#    reservation_status_hour
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming booking_data is your DataFrame containing the data
# Assuming 'reservation_status_date' is the datetime column

# Set 'reservation_status_date' as the index
hotel_data.set_index('reservation_status_date', inplace=True)

# Resample the data to monthly frequency and count the number of bookings
monthly_bookings = hotel_data.resample('M').size()

# Plot the time series of monthly bookings
plt.figure(figsize=(12, 6))
monthly_bookings.plot(marker='o', linestyle='-')
plt.title('Monthly Bookings Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Bookings')
plt.grid(True)
plt.show()

# Perform seasonal decomposition
decomposition = seasonal_decompose(monthly_bookings, model='additive')

# Plot the decomposition
plt.figure(figsize=(12, 8))

plt.subplot(411)
plt.plot(decomposition.observed)
plt.title('Observed')

plt.subplot(412)
plt.plot(decomposition.trend)
plt.title('Trend')

plt.subplot(413)
plt.plot(decomposition.seasonal)
plt.title('Seasonal')

plt.subplot(414)
plt.plot(decomposition.resid)
plt.title('Residual')

plt.tight_layout()
plt.show()
